# %% [markdown]
# <a href="https://colab.research.google.com/github/kiran2563/6267-CA2-DV-PROJECT/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data= pd.read_csv("/hotels.csv")

print(data)
# Out:
#                          address               name    area   roomTotal  \
# 0        10, Pranay Lake, Mumbai    "Golden Ribbon"  488590          50
# 1      88, Payal Heights, Cochin     "Lunar Garden"  375639         100
# 2  35, Chand Society, Darjeeling      "Elder Aegis"  284373          76
# 3          23, Amrita Nagar, Goa        "Moonlight"  352646         200
# 4            11, Malad, Guwahati   "Sublime Sierra"  420518          60
# 5             22, Ram Garh, Agra          "Nourish"  438311          48
#
#         type
# 0    "Hotel"
# 1   "Resort"
# 2   "Resort"
# 3    "Hotel"
# 4      "Inn"
# 5      "Inn"

# %%
import pandas as pd

data= pd.read_excel("/hotels.xlsx")

print(data)
# Out:
#                          address               name    area   roomTotal  \
# 0        10, Pranay Lake, Mumbai    "Golden Ribbon"  488590          50
# 1      88, Payal Heights, Cochin     "Lunar Garden"  375639         100
# 2  35, Chand Society, Darjeeling      "Elder Aegis"  284373          76
# 3          23, Amrita Nagar, Goa        "Moonlight"  352646         200
# 4            11, Malad, Guwahati   "Sublime Sierra"  420518          60
# 5             22, Ram Garh, Agra          "Nourish"  438311          48
#
#         type
# 0    "Hotel"
# 1   "Resort"
# 2   "Resort"
# 3    "Hotel"
# 4      "Inn"
# 5      "Inn"

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img=mpimg.imread("/pawar.jpg")
plt.imshow(img)
