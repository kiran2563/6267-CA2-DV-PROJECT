# %% [markdown]
# <a href="https://colab.research.google.com/github/kiran2563/6267-CA2-DV-PROJECT/blob/main/data_science_KP_prac7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame (
    {
        "roll no.":[6267,6266,6737,6239,6377,6488,6234,6245,6256],
        "name":['kiran','sayli','siddhu','sejal','sakshi','rushi','sahil','shrddha','chetan'],
        "marks":[90,80,56,78,89,79,97,94,96]

    }
)

# %%
print(df)
# Out:
#    roll no.     name  marks
# 0      6267    kiran     90
# 1      6266    sayli     80
# 2      6737   siddhu     56
# 3      6239    sejal     78
# 4      6377   sakshi     89
# 5      6488    rushi     79
# 6      6234    sahil     97
# 7      6245  shrddha     94
# 8      6256   chetan     96

# %%
df.isnull()
# Out:
#    roll no.   name  marks
# 0     False  False  False
# 1     False  False  False
# 2     False  False  False
# 3     False  False  False
# 4     False  False  False
# 5     False  False  False
# 6     False  False  False
# 7     False  False  False
# 8     False  False  False

# %%
df. describe()
# Out:
#           roll no.      marks
# count     9.000000   9.000000
# mean   6345.444444  84.333333
# std     169.166420  12.913172
# min    6234.000000  56.000000
# 25%    6245.000000  79.000000
# 50%    6266.000000  89.000000
# 75%    6377.000000  94.000000
# max    6737.000000  97.000000

# %%
df.describe(include='object')
# Out:
#          name
# count       9
# unique      9
# top     kiran
# freq        1

# %%
df.shape
# Out:
# (9, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   roll no.  9 non-null      int64
#  1   name      9 non-null      object
#  2   marks     9 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 344.0+ bytes

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# roll no.    9
# name        9
# marks       9
# dtype: int64

# %%
df['name'].value_counts()
# Out:
# kiran      1
# sayli      1
# siddhu     1
# sejal      1
# sakshi     1
# rushi      1
# sahil      1
# shrddha    1
# chetan     1
# Name: name, dtype: int64

# %%
correlation=df.corr()
# Out:
# <ipython-input-29-0c9b4bd1cb53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True,fmt='.3f',cmap='cool')
# Out:
# <Axes: >

# %%
df.var()
# Out:
# <ipython-input-39-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# roll no.    28617.277778
# marks         166.750000
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-41-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# roll no.    6345.444444
# marks         84.333333
# dtype: float64

# %%
df.cov()
# Out:
# <ipython-input-43-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#               roll no.        marks
# roll no.  28617.277778 -1819.916667
# marks     -1819.916667   166.750000

# %%
df.corr()
# Out:
# <ipython-input-44-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           roll no.     marks
# roll no.  1.000000 -0.833114
# marks    -0.833114  1.000000
